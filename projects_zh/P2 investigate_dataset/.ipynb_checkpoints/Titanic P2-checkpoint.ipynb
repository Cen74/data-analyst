# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/lihongcen/.pyenv/versions/anaconda-2.4.0/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['axes']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
titanic_data = pd.read_csv('titanic_data.csv')
print titanic_data.info()
print titanic_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# None
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 问题
# - 891名乘客的生存率是多少，与性别、ticket class 、是否小孩、妇女、老人更容易生存
# - 父母与小孩在不同tikect 下，谁更容易生存
# - 伴侣/兄妹之间谁更易生存

# %% [markdown]
# ### 查看数据有没有异常值

# %% [markdown]
# - 检查 survived 列里值是否有非(0,1)

# %% [markdown]
# - 通过图形分布看有没有异常值

# %%
fig, axes = plt.subplots(3, 1)
titanic_data['Pclass'].plot.hist(title='Pclass distribution', ax=axes[0],figsize=(10,10))
titanic_data['Age'].plot.hist(title='Age distribution', ax=axes[1])
titanic_data['PassengerId'].plot.hist(title='PassengerId distribution', ax=axes[2])

# figsize与layout size 的区别和设置

# %% [markdown]
# - 检查 PassgenId 的值是否唯一

# %%
len(titanic_data['PassengerId'].unique()) == len(titanic_data.index)
# Out:
# True

# %% [markdown]
# - describe 提供了更好的观察dataframe 的方式

# %%
titanic_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - 车票价格最高值为512有异常，找出3倍标准差以上的值，发现对应都是对应仓位1

# %%
fare = titanic_data['Fare']
abnormal_fare = fare > (fare.mean()+3*fare.std())
fare[abnormal_fare]
# Out:
# 27     263.0000
# 88     263.0000
# 118    247.5208
# 258    512.3292
# 299    247.5208
# 311    262.3750
# 341    263.0000
# 377    211.5000
# 380    227.5250
# 438    263.0000
# 527    221.7792
# 557    227.5250
# 679    512.3292
# 689    211.3375
# 700    227.5250
# 716    227.5250
# 730    211.3375
# 737    512.3292
# 742    262.3750
# 779    211.3375
# Name: Fare, dtype: float64

# %%
titanic_data.groupby('Pclass').mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
titanic_data['Pclass'][abnormal_fare]
# Out:
# 27     1
# 88     1
# 118    1
# 258    1
# 299    1
# 311    1
# 341    1
# 377    1
# 380    1
# 438    1
# 527    1
# 557    1
# 679    1
# 689    1
# 700    1
# 716    1
# 730    1
# 737    1
# 742    1
# 779    1
# Name: Pclass, dtype: int64

# %% [markdown]
# - 查询不同等级的金额范围，发现都有票价为0的情况，最高值都显著大于平均值

# %%
titanic_data.groupby('Pclass')['Fare'].apply(lambda x: (x.min(), x.max()))
# Out:
# Pclass
# 1    (0.0, 512.3292)
# 2        (0.0, 73.5)
# 3       (0.0, 69.55)
# Name: Fare, dtype: object

# %% [markdown]
# - 分析Pclass 为1，且 fare=0 的乘客的名字没有发现关联

# %%
Pclass_1_fare_0 = (titanic_data['Pclass'] == 1) & (titanic_data_c['Fare'] == 0)
print titanic_data[Pclass_1_fare_0]['Name']
print titanic_data.iloc[titanic_data['Fare'].argmax()]['Name']
# Out:
# 263              Harrison, Mr. William
# 633      Parr, Mr. William Henry Marsh
# 806             Andrews, Mr. Thomas Jr
# 815                   Fry, Mr. Richard
# 822    Reuchlin, Jonkheer. John George
# Name: Name, dtype: object
# Ward, Miss. Anna

# %% [markdown]
# - 结论：未找到fare分布异常的原因

# %% [markdown]
# - 将Sex 中的 male 替换为0， female 替换为1，方便统计
# - 创建 titanic_data_c 副本，在此基础上对数据进行操作。

# %%
# titanic_data_c['Sex'].plot.bar() 直接用柱状图形不成分类，用直方图不接受非数字


# sex 类别需转换为数字, male 为0， female 为 1
titanic_data_c = titanic_data.copy() #创建一个copy
Sex = titanic_data_c['Sex']
Sex[Sex=='male'] = 0
Sex[Sex=='female'] = 1

titanic_data_c['Sex'].plot.hist(title='gender distribution')

# 另外一种方式 replace 
# titanic_data['Sex] = titanic_data['Sex'].replace(['male', 'female'], [0, 1])
# Out:
# /Users/lihongcen/.pyenv/versions/anaconda-2.4.0/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/lihongcen/.pyenv/versions/anaconda-2.4.0/lib/python2.7/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Q1: 整体生存率多少，性别、年龄、仓位等级是否生存率有明显差异

# %%
total_survived_rate = titanic_data['Survived'].sum() / float(len(titanic_data.index))
print "The whole population survived rate is: ", total_survived_rate


def survived_by_field(data, filed):
    groups = data.groupby(filed)
    
    survived_num = groups.sum()['Survived']
    total_num = groups.count()['Survived']
    percent = survived_num / total_num 
    
    table = pd.concat([survived_num, total_num, percent], axis=1)
    table.columns = ['survived', 'total', 'percent']

    table.plot.bar(use_index=False, table=True, figsize=(8, 5))  #table 要修改距离 
    #print "The percentage is:\n"
    #print percent
    

survived_by_field(titanic_data, 'Pclass')
survived_by_field(titanic_data_c, 'Sex')




#survived_percent.plot.barh()
#plt.bar(Pclass_group.count()['Survived'].index, Pclass_group.count()['Survived'].values)
# Out:
# The whole population survived rate is:  0.383838383838

# %% [markdown]
# 结论:
# - 头等舱的生存率显著高于平均值为 0.62
# - 女性的生存率也明显高于男性为 0.74， 可能是妇女能到优先救助

# %%
titanic_data_c['Age Group'] = pd.cut(titanic_data_c['Age'], bins=[0,6,18,30,60,90])

survived_by_field(titanic_data_c, 'Age Group')

# %% [markdown]
# 结论：
# - 0-6岁小孩生存率最高0.70，中年30-60岁和少年6-18岁生存率要高于青年18-30岁，60岁以上人群生存率很低。

# %% [markdown]
# ## Q2: 父母与小孩的生存率比较，父母会不会把生存机会让给了孩子

# %%
#titanic_data_c['Parch'].plot.hist()
survived_by_field(titanic_data_c, 'Parch')

# %% [markdown]
# - 从上表可看出有Parch 的生存率高于平均生存率, 新建Family列，对Parch进行分类

# %%
titanic_data_c['Family'] = (titanic_data_c['Parch'] != 0)
survived_by_field(titanic_data_c, 'Family')

# %% [markdown]
# - 将有Parch关系的乘客归类，Parch生存率明显较高为0.51
# - 对Parch类乘客进行年龄段划分，查看生存率差异

# %%
titanic_data_c['Age Group2'] = pd.cut(titanic_data_c['Age'], bins=[0,6,18,30,60,90])
survived_by_field(titanic_data_c[titanic_data_c['Family']], 'Age Group2')

# %% [markdown]
# 结论：
# - 在有Parch关系的乘客中，0-60岁的生存率都高于平均生存率0.38，最高的是0-6岁群体，这应该是小孩更易得到照顾。
# - 6-18岁群体，生存率较低0.42，不清楚原因
# - 从数据上低年龄乘客和成年乘客的生存率都高于平均值，难以判断是否有父母把生存机会让给孩子的情况出线，如果有家庭数据可能能够进一步分析，从名字关系分析也许是个思路。

# %% [markdown]
# ## Q3：伴侣、兄妹之间哪种性别更易生存？

# %% [markdown]
# - 建立‘Related’列，值为True 表示有伴侣或兄妹
# - 查看'Related' 为 True 时，男、女性的生存机率，与整体性别的差异不明显。

# %%
# titanic_data_c['SibSp'].plot.hist()
titanic_data_c['Related'] = (titanic_data_c['SibSp'] != 0)
survived_by_field(titanic_data_c[titanic_data_c['Related']], 'Sex')
survived_by_field(titanic_data_c, 'Sex')

# %% [markdown]
# - Related 为 True 时，群体生存概率更高, 但与平均值差异不明显。

# %%
survived_by_field(titanic_data_c, 'Related')
